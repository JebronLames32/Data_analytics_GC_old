# %%
# importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# extract the dataset from the excel file and store it in a dataframe
df = pd.read_excel('Train_data.xlsx')
# print(df.keys())

# drop the columns which are not required for the prediction
df.drop('Region', axis=1, inplace=True)

# print the first 5 rows of the dataframe of key Warehouse id
print(df['Warehouse id'].head())


df.head()
# Out:
# 0    Wh-1
# 1    Wh-1
# 2    Wh-1
# 3    Wh-1
# 4    Wh-1
# Name: Warehouse id, dtype: object
#   Warehouse id SKU id  2018-04-01 00:00:00  2018-05-01 00:00:00  \
# 0         Wh-1  SKU-1                   27                   13
# 1         Wh-1  SKU-2                   88                   28
# 2         Wh-1  SKU-3                    6                    6
# 3         Wh-1  SKU-4                  162                  184
# 4         Wh-1  SKU-5                  171                  402
#
#    2018-06-01 00:00:00  2018-07-01 00:00:00  2018-08-01 00:00:00  \
# 0                   30                   14                   22
# 1                  127                  130                   58
# 2                    6                    6                    6
# 3                  110                  172                   90
# 4                  627                  615                  300
#
#    2018-09-01 00:00:00  2018-10-01 00:00:00  2018-11-01 00:00:00  ...  \
# ...

# %%
# divide the dataset based on the warehouse number.
df1 = df[df['Warehouse id'] == 'Wh-1']
df2 = df[df['Warehouse id'] == 'Wh-2']
df3 = df[df['Warehouse id'] == 'Wh-3']
df4 = df[df['Warehouse id'] == 'Wh-4']

# drop the columns which are not required for the prediction
df1.drop('Warehouse id', axis=1, inplace=True)
df2.drop('Warehouse id', axis=1, inplace=True)
df3.drop('Warehouse id', axis=1, inplace=True)
df4.drop('Warehouse id', axis=1, inplace=True)

df1.head()
# Out:
# /tmp/ipykernel_17185/4188201384.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop('Warehouse id', axis=1, inplace=True)
# /tmp/ipykernel_17185/4188201384.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.drop('Warehouse id', axis=1, inplace=True)
# /tmp/ipykernel_17185/4188201384.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3.drop('Warehouse id', axis=1, inplace=True)
# ...

# %%
df2.head()
# Out:
#     Warehouse id Region SKU id  2018-04-01 00:00:00  2018-05-01 00:00:00  \
# 233         Wh-2   EAST  SKU-1                   23                   20
# 234         Wh-2   EAST  SKU-2                   20                   18
# 235         Wh-2   EAST  SKU-3                   22                   25
# 236         Wh-2   EAST  SKU-4                   80                   62
# 237         Wh-2   EAST  SKU-5                  277                  357
#
#      2018-06-01 00:00:00  2018-07-01 00:00:00  2018-08-01 00:00:00  \
# 233                   11                   23                   53
# 234                   19                   18                    9
# 235                    7                    7                    7
# 236                   80                   60                    6
# 237                  357                  229                  221
#
#      2018-09-01 00:00:00  2018-10-01 00:00:00  ...  2020-08-01 00:00:00  \
# ...
